# %% [markdown]
# <a href="https://colab.research.google.com/github/VishnuRathore98/jupyter/blob/main/car_damage_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)

# %%
# import cv2
from google.colab.patches import cv2_imshow
from ultralytics import YOLO
img_pth = "10.jpg"
model = YOLO("best.pt")
results = model(source=img_pth)
res_plotted = results[0].plot()
cv2_imshow(res_plotted)
# Out:
# image 1/1 /content/10.jpg: 640x640 1 damaged wind shield, 326.6ms
# Speed: 8.6ms preprocess, 326.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=224x224>
