# %% [markdown]
# # Scikit-Learn

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression # importing the linear regression model

# %%
rng = np.random.RandomState(42)
x = 10 * rng.rand(50)
y = 2 * x - 1 + rng.randn(50)
plt.scatter(x,y)                  # plotting the values on graph

# %%
model = LinearRegression(fit_intercept=True)

# %%
model
# Out:
# LinearRegression()

# %%
X = x[:, np.newaxis]
X.shape
# Out:
# (50, 1)

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([1.9776566])

# %%
model.intercept_
# Out:
# np.float64(-0.9033107255311146)

# %%
xfit = np.linspace(-1,11)
